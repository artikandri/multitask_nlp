# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('../../../')
from collections import Counter
from typing import List, Tuple

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from datasets import load_dataset
from multitask_nlp.settings import DATASETS_DIR

tqdm.pandas()

dataset_path = DATASETS_DIR / 'poleval2018'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def read_file(filepath: str) -> List[Tuple[str, List[str], List[str]]]:
    data = []
    sentence_tokens = []
    tags = []

    f = open(filepath, encoding='UTF-8')
    for i, line in enumerate(f, 1):
        if not line.strip() or len(line) == 0 or line.startswith('-DOCSTART') or line[0] == "\n":
            if len(sentence_tokens) > 0:
                sentence = ' '.join(sentence_tokens)
                data.append((sentence, sentence_tokens, tags))
                sentence_tokens = []
                tags = []
            continue

        splits = line.split('\t')
        assert len(splits) >= 2, "error on line {}. Found {} splits".format(i, len(splits))
        word, tag = splits[0], splits[2]
        sentence_tokens.append(word.strip())
        tags.append(tag.strip())

    if len(sentence_tokens) > 0:
        sentence = ' '.join(sentence_tokens)
        data.append((sentence, sentence_tokens, tags))

    f.close()
    return data

text_ids, texts, texts_tokens, tags = [], [], [], []

files = os.listdir(dataset_path)
files = list(filter(lambda x: x.split('.')[1] == 'iob', files))

text_id = 1

for f_name in tqdm(files):
    data = read_file(dataset_path / f_name)
    for sentence, sentence_tokens, sentence_tags in data:
        texts.append(sentence)
        texts_tokens.append(sentence_tokens)
        tags.append(sentence_tags)
        text_id += 1
# Out:
#   0%|          | 0/1828 [00:00<?, ?it/s]

# %%
assert all([len(tokens) == len(texts_tags) for tokens, texts_tags 
            in zip(texts_tokens, tags)])

# %%
len(texts)
# Out:
# 36096

# %%
all_tags = [t for sent_tags in tags for t in sent_tags]

# %%
len(all_tags)
# Out:
# 540545

# %%
counter = Counter(all_tags)

# %%
counter.most_common()
# Out:
# [('interp', 95364),
#  ('qub', 29958),
#  ('conj', 19503),
#  ('fin:sg:ter:imperf', 14412),
#  ('subst:sg:gen:f', 13684),
#  ('prep:loc:nwok', 12074),
#  ('subst:sg:nom:m1', 11337),
#  ('subst:sg:nom:f', 10855),
#  ('subst:sg:gen:m3', 10308),
#  ('adv', 9078),
#  ('adv:pos', 8829),
#  ('comp', 8493),
#  ('prep:gen', 8082),
#  ('prep:acc', 7739),
#  ('subst:sg:nom:m3', 7389),
#  ('prep:loc', 7078),
#  ('subst:sg:acc:f', 6545),
#  ('subst:sg:loc:m3', 6356),
#  ('prep:gen:nwok', 6202),
#  ('subst:sg:acc:m3', 6182),
#  ('subst:sg:gen:n', 6108),
#  ('subst:sg:nom:n', 5586),
#  ('subst:sg:loc:f', 5252),
#  ('inf:perf', 4991),
#  ('brev:pun', 4942),
#  ('fin:pl:ter:imperf', 4917),
#  ('subst:pl:gen:m3', 4760),
#  ('subst:pl:gen:f', 4674),
#  ('subst:sg:acc:n', 4590),
#  ('adj:sg:nom:f:pos', 4545),
#  ('adj:sg:gen:f:pos', 4462),
#  ('prep:inst:nwok', 4419),
#  ('adj:sg:gen:m3:pos', 4174),
#  ('inf:imperf', 4136),
#  ('praet:sg:m1:perf', 4089),
#  ('subst:sg:gen:m1', 3953),
#  ('adj:sg:nom:m3:pos', 3861),
#  ('pred', 3252),
#  ('prep:acc:nwok', 3222),
#  ('praet:sg:m1:imperf', 3208),
#  ('subst:sg:inst:f', 2964),
#  ('fin:sg:pri:imperf', 2884),
#  ('subst:pl:gen:m1', 2861),
#  ('subst:sg:inst:m3', 2696),
#  ('adj:sg:loc:m3:pos', 2650),
#  ('subst:pl:gen:n', 2577),
#  ('subst:pl:nom:m1', 2537),
#  ('subst:sg:loc:n', 2530),
#  ('subst:pl:acc:m3', 2495),
#  ('adj:sg:acc:m3:pos', 2492),
#  ('adj:sg:acc:f:pos', 2467),
#  ('adj:sg:nom:n:pos', 2372),
#  ('adj:sg:nom:m1:pos', 2358),
#  ('praet:sg:f:perf', 2354),
#  ('subst:pl:acc:f', 2266),
#  ('subst:pl:nom:f', 2220),
#  ('praet:sg:f:imperf', 2053),
#  ('subst:pl:nom:m3', 2027),
#  ('adj:sg:loc:f:pos', 1996),
#  ('adj:pl:gen:f:pos', 1976),
#  ('num:pl:nom:m3:congr', 1916),
#  ('adj:pl:nom:f:pos', 1795),
#  ('adj:pl:gen:m3:pos', 1751),
#  ('adj:sg:gen:n:pos', 1744),
#  ('fin:sg:ter:perf', 1730),
#  ('subst:sg:inst:n', 1626),
#  ('praet:sg:n:imperf', 1624),
#  ('praet:pl:m1:imperf', 1511),
#  ('praet:pl:m1:perf', 1422),
#  ('adj:pl:nom:m3:pos', 1338),
#  ('fin:pl:pri:imperf', 1334),
#  ('adj:pl:nom:m1:pos', 1285),
#  ('adv:com', 1284),
#  ('subst:pl:loc:m3', 1281),
#  ('subst:pl:acc:n', 1252),
#  ('subst:sg:inst:m1', 1238),
#  ('subst:sg:acc:m1', 1224),
#  ('adj:pl:acc:f:pos', 1208),
#  ('subst:pl:nom:n', 1193),
#  ('adj:sg:acc:n:pos', 1183),
#  ('pcon:imperf', 1179),
#  ('praet:sg:n:perf', 1170),
#  ('ger:sg:gen:n:imperf:aff', 1149),
#  ('ger:sg:gen:n:perf:aff', 1135),
#  ('adj:sg:inst:m3:pos', 1129),
#  ('adj:pl:acc:m3:pos', 1091),
#  ('num:pl:acc:m3:congr', 1070),
#  ('adj:sg:inst:f:pos', 1034),
#  ('aglt:sg:pri:imperf:wok', 1024),
#  ('subst:pl:loc:f', 1023),
#  ('subst:pl:loc:n', 1004),
#  ('adj:pl:gen:n:pos', 947),
#  ('fin:sg:sec:imperf', 911),
#  ('adj:pl:gen:m1:pos', 861),
#  ('adj:pl:nom:n:pos', 852),
#  ('num:pl:gen:m3:congr', 824),
#  ('aglt:sg:pri:imperf:nwok', 813),
#  ('adj:sg:loc:n:pos', 793),
#  ('bedzie:sg:ter:imperf', 791),
#  ('praet:sg:m3:perf', 786),
#  ('prep:inst', 756),
#  ('aglt:pl:pri:imperf:nwok', 744),
#  ('num:pl:acc:m3:rec', 712),
#  ('imps:perf', 701),
#  ('subst:pl:inst:m3', 687),
#  ('brev:npun', 687),
#  ('praet:sg:m3:imperf', 682),
#  ('adj:pl:loc:m3:pos', 648),
#  ('interj', 645),
#  ('subst:pl:acc:m1', 626),
#  ('adj:pl:acc:n:pos', 621),
#  ('ger:sg:acc:n:perf:aff', 613),
#  ('siebie:dat', 597),
#  ('ppron3:sg:gen:m1:ter:akc:npraep', 567),
#  ('subst:pl:inst:f', 566),
#  ('adj:sg:gen:m1:pos', 552),
#  ('praet:pl:f:imperf', 550),
#  ('adj:pl:loc:f:pos', 541),
#  ('subst:sg:dat:m1', 528),
#  ('fin:pl:ter:perf', 524),
#  ('prep:inst:wok', 524),
#  ('ppas:sg:nom:f:perf:aff', 523),
#  ('num:pl:nom:f:congr', 519),
#  ('adj:sg:inst:n:pos', 516),
#  ('impt:sg:sec:perf', 496),
#  ('subst:sg:nom:m2', 492),
#  ('adv:sup', 479),
#  ('ppron12:sg:nom:m1:pri', 473),
#  ('subst:sg:dat:f', 472),
#  ('ger:sg:nom:n:perf:aff', 467),
#  ('ppron3:sg:gen:f:ter:akc:npraep', 462),
#  ('prep:gen:wok', 453),
#  ('ppas:sg:nom:m3:perf:aff', 439),
#  ('praet:pl:f:perf', 438),
#  ('ger:sg:nom:n:imperf:aff', 394),
#  ('ppron12:sg:dat:m1:pri:nakc', 381),
#  ('fin:sg:pri:perf', 380),
#  ('adj:sg:inst:m1:pos', 369),
#  ('ger:sg:loc:n:perf:aff', 363),
#  ('ppron3:sg:dat:m1:ter:nakc:npraep', 361),
#  ('subst:pl:inst:n', 361),
#  ('praet:pl:m3:imperf', 357),
#  ('prep:nom', 356),
#  ('subst:pl:inst:m1', 353),
#  ('subst:pl:dat:m1', 350),
#  ('impt:sg:sec:imperf', 348),
#  ('ppas:sg:nom:m1:perf:aff', 344),
#  ('subst:sg:voc:m1', 341),
#  ('adj:pl:loc:n:pos', 336),
#  ('subst:pl:gen:m2', 328),
#  ('prep:dat', 312),
#  ('adj:pl:inst:f:pos', 308),
#  ('ppron3:sg:nom:m1:ter:akc:npraep', 303),
#  ('ppron3:sg:acc:m1:ter:nakc:npraep', 299),
#  ('bedzie:pl:ter:imperf', 293),
#  ('fin:pl:pri:perf', 291),
#  ('num:pl:acc:f:rec', 283),
#  ('ppron3:sg:acc:f:ter:akc:npraep', 279),
#  ('adj:pl:inst:m3:pos', 274),
#  ('adj:sg:acc:m1:pos', 273),
#  ('ger:sg:acc:n:imperf:aff', 272),
#  ('ppas:pl:nom:f:perf:aff', 269),
#  ('ppron3:pl:gen:m1:ter:akc:npraep', 267),
#  ('ppas:pl:nom:m3:perf:aff', 265),
#  ('ppron12:sg:nom:f:pri', 261),
#  ('ppron12:pl:dat:m1:pri', 259),
#  ('ppron3:sg:nom:f:ter:akc:npraep', 258),
#  ('num:pl:nom:m3:rec', 250),
#  ('praet:pl:m3:perf', 246),
#  ('num:pl:acc:f:congr', 245),
#  ('subst:sg:gen:m2', 245),
#  ('ppas:sg:nom:n:perf:aff', 235),
#  ('ppron12:sg:acc:m1:pri:akc', 234),
#  ('imps:imperf', 232),
#  ('num:pl:nom:m1:rec', 230),
#  ('num:pl:acc:n:rec', 228),
#  ('num:pl:nom:f:rec', 228),
#  ('adj:pl:acc:m1:pos', 219),
#  ('subst:sg:dat:n', 219),
#  ('xxx', 219),
#  ('prep:loc:wok', 213),
#  ('num:pl:gen:f:congr', 204),
#  ('ppas:sg:nom:f:imperf:aff', 204),
#  ('ger:sg:loc:n:imperf:aff', 202),
#  ('fin:sg:sec:perf', 198),
#  ('subst:sg:acc:m2', 191),
#  ('adjp', 188),
#  ('praet:pl:n:imperf', 187),
#  ('num:pl:loc:m3:congr', 185),
#  ('ppas:sg:gen:f:perf:aff', 185),
#  ('ppron3:pl:dat:m1:ter:akc:npraep', 184),
#  ('num:pl:nom:m1:congr', 184),
#  ('ppron12:pl:gen:m1:pri', 183),
#  ('ppron12:sg:gen:m1:pri:akc', 182),
#  ('ppas:pl:nom:m1:perf:aff', 181),
#  ('ger:sg:inst:n:perf:aff', 176),
#  ('ppas:pl:gen:m3:perf:aff', 173),
#  ('aglt:sg:sec:imperf:nwok', 173),
#  ('pact:sg:nom:f:imperf:aff', 172),
#  ('pact:sg:nom:m1:imperf:aff', 171),
#  ('ppas:pl:gen:f:perf:aff', 170),
#  ('subst:pl:dat:f', 167),
#  ('ppron12:sg:dat:m1:sec:nakc', 167),
#  ('ppron3:sg:dat:f:ter:akc:npraep', 167),
#  ('subst:sg:voc:f', 164),
#  ('ppron12:pl:acc:m1:pri', 162),
#  ('subst:pl:nom:m2', 161),
#  ('siebie:gen', 160),
#  ('subst:sg:loc:m1', 156),
#  ('ppron12:sg:dat:f:pri:nakc', 155),
#  ('ppas:sg:nom:m3:imperf:aff', 154),
#  ('ppron12:sg:nom:m1:sec', 153),
#  ('praet:pl:n:perf', 152),
#  ('pact:pl:gen:f:imperf:aff', 146),
#  ('num:pl:nom:n:rec', 145),
#  ('aglt:sg:sec:imperf:wok', 144),
#  ('num:pl:acc:m2:congr', 143),
#  ('praet:sg:m1:imperf:nagl', 142),
#  ('ppron3:pl:gen:f:ter:akc:npraep', 142),
#  ('ppas:pl:nom:f:imperf:aff', 142),
#  ('pact:sg:gen:f:imperf:aff', 142),
#  ('ppron3:pl:gen:m1:ter:akc:praep', 140),
#  ('adj:pl:inst:n:pos', 136),
#  ('pact:pl:gen:m3:imperf:aff', 136),
#  ('adj:sg:dat:f:pos', 134),
#  ('pact:pl:gen:m1:imperf:aff', 133),
#  ('adj:sg:dat:m1:pos', 131),
#  ('subst:sg:dat:m3', 131),
#  ('ppas:sg:acc:f:perf:aff', 127),
#  ('ppas:pl:nom:n:perf:aff', 125),
#  ('ppas:sg:gen:m3:perf:aff', 124),
#  ('adj:sg:nom:f:com', 123),
#  ('ppas:pl:nom:m3:imperf:aff', 121),
#  ('pact:sg:nom:m3:imperf:aff', 119),
#  ('impt:pl:pri:perf', 119),
#  ('ppron3:pl:nom:m1:ter:akc:npraep', 118),
#  ('adj:pl:dat:m1:pos', 116),
#  ('ppron3:sg:gen:m3:ter:akc:npraep', 114),
#  ('ppron12:pl:nom:m1:pri', 114),
#  ('ppas:pl:acc:m3:perf:aff', 114),
#  ('ger:sg:inst:n:imperf:aff', 113),
#  ('num:pl:gen:m1:congr', 113),
#  ('ppron3:sg:inst:m1:ter:akc:npraep', 111),
#  ('pact:pl:nom:f:imperf:aff', 111),
#  ('siebie:inst', 108),
#  ('adj:pl:inst:m1:pos', 107),
#  ('bedzie:pl:pri:imperf', 106),
#  ('burk', 106),
#  ('pact:sg:acc:f:imperf:aff', 104),
#  ('fin:pl:sec:imperf', 104),
#  ('ppron3:pl:acc:m1:ter:akc:npraep', 103),
#  ('ppron3:pl:gen:m3:ter:akc:npraep', 102),
#  ('ppron3:sg:acc:m3:ter:nakc:npraep', 99),
#  ('ppron3:sg:gen:f:ter:akc:praep', 99),
#  ('ppron3:pl:acc:m3:ter:akc:npraep', 98),
#  ('subst:pl:dat:m3', 96),
#  ('pact:sg:gen:m3:imperf:aff', 95),
#  ('ppron3:pl:acc:f:ter:akc:npraep', 94),
#  ('bedzie:sg:pri:imperf', 93),
#  ('ppas:sg:nom:n:imperf:aff', 93),
#  ('subst:pl:dat:n', 93),
#  ('subst:pl:acc:m2', 92),
#  ('ppron3:sg:gen:m1:ter:akc:praep', 92),
#  ('num:pl:nom:n:congr', 92),
#  ('ppas:sg:acc:m3:perf:aff', 91),
#  ('ppas:pl:gen:m3:imperf:aff', 91),
#  ('siebie:acc', 89),
#  ('num:pl:acc:m1:rec', 89),
#  ('adj:sg:nom:m3:com', 89),
#  ('adj:sg:nom:m2:pos', 88),
#  ('pact:sg:acc:m3:imperf:aff', 87),
#  ('ppas:sg:gen:f:imperf:aff', 87),
#  ('ppron3:pl:nom:f:ter:akc:npraep', 85),
#  ('winien:sg:f:imperf', 84),
#  ('ppas:pl:gen:m1:perf:aff', 84),
#  ('ppas:pl:acc:f:perf:aff', 83),
#  ('subst:sg:inst:m2', 83),
#  ('siebie:loc', 79),
#  ('ppas:sg:loc:m3:perf:aff', 79),
#  ('ppas:sg:nom:m1:imperf:aff', 79),
#  ('pact:pl:acc:m3:imperf:aff', 79),
#  ('winien:sg:m1:imperf', 77),
#  ('num:pl:nom:m2:congr', 76),
#  ('pant:perf', 75),
#  ('ppron3:sg:loc:f:ter:akc:npraep', 75),
#  ('adj:pl:dat:f:pos', 74),
#  ('ppas:pl:gen:n:perf:aff', 74),
#  ('num:pl:loc:f:congr', 73),
#  ('adj:sg:nom:f:sup', 73),
#  ('pact:pl:nom:m3:imperf:aff', 71),
#  ('ppas:sg:loc:f:perf:aff', 71),
#  ('ppron12:sg:acc:m1:sec:nakc', 70),
#  ('ppron3:sg:gen:n:ter:akc:npraep', 70),
#  ('ppron12:sg:acc:f:pri:akc', 70),
#  ('winien:sg:n:imperf', 68),
#  ('praet:sg:m1:perf:nagl', 67),
#  ('ppas:pl:nom:m1:imperf:aff', 67),
#  ('adj:pl:nom:m2:pos', 67),
#  ('pact:pl:acc:f:imperf:aff', 66),
#  ('ppas:sg:inst:m3:perf:aff', 66),
#  ('ppas:pl:gen:f:imperf:aff', 66),
#  ('adj:sg:nom:n:com', 66),
#  ('ppron3:sg:acc:m1:ter:akc:praep', 65),
#  ('ppron3:pl:gen:f:ter:akc:praep', 64),
#  ('ppron3:sg:nom:m3:ter:akc:npraep', 64),
#  ('adja', 62),
#  ('ppron3:sg:loc:m3:ter:akc:npraep', 62),
#  ('ppron3:sg:inst:f:ter:akc:praep', 60),
#  ('subst:pl:loc:m1', 60),
#  ('ppas:sg:inst:f:perf:aff', 60),
#  ('prep:acc:wok', 59),
#  ('adj:pl:dat:m3:pos', 58),
#  ('ppron3:sg:acc:f:ter:akc:praep', 57),
#  ('adj:sg:nom:m3:sup', 57),
#  ('adj:sg:acc:f:com', 57),
#  ('adj:sg:dat:n:pos', 57),
#  ('winien:pl:m1:imperf', 57),
#  ('ppron3:pl:gen:n:ter:akc:npraep', 56),
#  ('pact:sg:inst:m3:imperf:aff', 56),
#  ('ppas:sg:gen:m3:imperf:aff', 56),
#  ('ppron12:sg:nom:f:sec', 56),
#  ('num:pl:acc:n:congr', 55),
#  ('adj:sg:gen:f:com', 54),
#  ('ppron3:pl:nom:m3:ter:akc:npraep', 53),
#  ('pact:sg:gen:m1:imperf:aff', 53),
#  ('ppas:sg:gen:n:perf:aff', 53),
#  ('ppron3:pl:inst:m1:ter:akc:npraep', 53),
#  ('adj:sg:nom:n:sup', 52),
#  ('impt:pl:pri:imperf', 51),
#  ('ppas:pl:nom:n:imperf:aff', 50),
#  ('adj:sg:dat:m3:pos', 50),
#  ('ppron3:pl:acc:n:ter:akc:npraep', 50),
#  ('adj:pl:nom:f:com', 50),
#  ('ppron12:sg:dat:f:sec:nakc', 49),
#  ('ppron12:sg:gen:f:pri:akc', 48),
#  ('adj:sg:acc:m2:pos', 48),
#  ('bedzie:sg:sec:imperf', 48),
#  ('num:pl:gen:n:congr', 48),
#  ('ppas:pl:acc:n:perf:aff', 46),
#  ('adj:sg:acc:n:com', 45),
#  ('aglt:pl:sec:imperf:nwok', 45),
#  ('ppas:sg:acc:n:perf:aff', 45),
#  ('subst:sg:loc:m2', 45),
#  ('pact:pl:acc:n:imperf:aff', 44),
#  ('ppron3:sg:gen:m1:ter:nakc:npraep', 44),
#  ('adj:pl:nom:m3:com', 43),
#  ('impt:pl:sec:imperf', 43),
#  ('adj:sg:gen:n:com', 43),
#  ('depr:pl:nom:m2', 43),
#  ('pact:pl:gen:n:imperf:aff', 43),
#  ('ppron3:sg:nom:n:ter:akc:npraep', 43),
#  ('winien:sg:m3:imperf', 42),
#  ('num:pl:gen:m2:congr', 41),
#  ('adj:sg:acc:m3:com', 41),
#  ('ppas:pl:loc:m3:perf:aff', 41),
#  ('ppron12:pl:nom:m1:sec', 40),
#  ('adj:sg:acc:m3:sup', 40),
#  ('ppron12:pl:inst:m1:pri', 40),
#  ('pact:sg:gen:n:imperf:aff', 39),
#  ('ger:sg:dat:n:perf:aff', 39),
#  ('pact:sg:inst:f:imperf:aff', 39),
#  ('adj:pl:gen:f:sup', 39),
#  ('num:pl:inst:m3:congr', 39),
#  ('praet:sg:m2:perf', 38),
#  ('ppas:pl:loc:f:perf:aff', 38),
#  ('adj:pl:gen:f:com', 38),
#  ('ppas:pl:inst:f:perf:aff', 38),
#  ('ppron3:sg:gen:m3:ter:nakc:npraep', 37),
#  ('ppron12:sg:gen:m1:sec:akc', 37),
#  ('impt:pl:sec:perf', 36),
#  ('adj:pl:gen:m3:sup', 35),
#  ('ppas:sg:acc:f:imperf:aff', 35),
#  ('adj:pl:acc:m3:com', 35),
#  ('ppas:pl:gen:n:imperf:aff', 35),
#  ('adj:sg:inst:f:sup', 35),
#  ('adj:sg:loc:f:com', 35),
#  ('adj:sg:acc:f:sup', 35),
#  ('adj:sg:loc:m3:com', 34),
#  ('adj:pl:nom:m1:com', 34),
#  ('winien:pl:f:imperf', 33),
#  ('pact:pl:nom:m1:imperf:aff', 33),
#  ('pact:pl:nom:n:imperf:aff', 33),
#  ('adj:sg:gen:f:sup', 33),
#  ('adj:sg:nom:m1:com', 33),
#  ('adj:pl:gen:m1:sup', 33),
#  ('adj:pl:gen:m2:pos', 32),
#  ('ppas:pl:acc:m3:imperf:aff', 32),
#  ('ppron3:pl:dat:f:ter:akc:npraep', 32),
#  ('num:pl:acc:m1:congr', 32),
#  ('ppron12:sg:inst:m1:pri', 32),
#  ('adj:sg:gen:m2:pos', 31),
#  ('adj:pl:acc:m2:pos', 30),
#  ('subst:pl:inst:m2', 30),
#  ('pact:sg:nom:n:imperf:aff', 30),
#  ('adj:pl:dat:n:pos', 30),
#  ('adj:sg:nom:m1:sup', 30),
#  ('ppas:sg:loc:n:perf:aff', 30),
#  ('ppas:pl:loc:n:perf:aff', 29),
#  ('num:pl:loc:n:congr', 29),
#  ('ppron3:sg:loc:m1:ter:akc:npraep', 29),
#  ('adj:sg:loc:m3:sup', 29),
#  ('adj:pl:acc:f:com', 29),
#  ('ppas:pl:inst:m3:perf:aff', 28),
#  ('ppas:sg:inst:n:perf:aff', 28),
#  ('num:pl:acc:m2:rec', 28),
#  ('praet:sg:m2:imperf', 28),
#  ('adj:pl:acc:m3:sup', 28),
#  ('ppron12:pl:dat:m1:sec', 28),
#  ('fin:pl:sec:perf', 28),
#  ('praet:sg:m3:imperf:nagl', 27),
#  ('pact:pl:loc:m3:imperf:aff', 27),
#  ('pact:sg:loc:f:imperf:aff', 26),
#  ('ppas:sg:gen:m1:perf:aff', 26),
#  ('pact:pl:loc:f:imperf:aff', 26),
#  ('adj:sg:loc:m1:pos', 26),
#  ('adj:sg:inst:m3:sup', 26),
#  ('praet:sg:m1:imperf:agl', 25),
#  ('adj:sg:gen:m3:com', 25),
#  ('adj:sg:gen:m3:sup', 25),
#  ('ger:sg:dat:n:imperf:aff', 25),
#  ('ppas:pl:gen:m1:imperf:aff', 25),
#  ('adj:pl:gen:m3:com', 25),
#  ('ppas:sg:loc:f:imperf:aff', 24),
#  ('ppron3:sg:acc:n:ter:akc:npraep', 24),
#  ('winien:pl:m3:imperf', 24),
#  ('pact:pl:inst:m3:imperf:aff', 24),
#  ('ppas:pl:acc:f:imperf:aff', 24),
#  ('adj:sg:voc:m1:pos', 23),
#  ('ppron12:pl:gen:m1:sec', 23),
#  ('ppas:sg:loc:m3:imperf:aff', 23),
#  ('ppron12:sg:dat:m1:pri:akc', 23),
#  ('ppron12:sg:acc:f:sec:nakc', 23),
#  ('pact:sg:loc:m3:imperf:aff', 23),
#  ('ppron3:pl:gen:m3:ter:akc:praep', 22),
#  ('adj:sg:voc:f:pos', 22),
#  ('ppron12:sg:acc:m1:sec:akc', 22),
#  ('adj:pl:loc:m1:pos', 22),
#  ('adj:sg:inst:n:sup', 22),
#  ('adj:sg:acc:n:sup', 21),
#  ('ppron3:pl:loc:n:ter:akc:praep', 21),
#  ('ppron3:pl:inst:f:ter:akc:npraep', 21),
#  ('num:pl:nom:m2:rec', 21),
#  ('pact:sg:inst:m1:imperf:aff', 20),
#  ('ppron12:pl:acc:m1:sec', 20),
#  ('ppron3:pl:gen:n:ter:akc:praep', 20),
#  ('pact:sg:acc:m1:imperf:aff', 20),
#  ('adj:pl:nom:m3:sup', 19),
#  ('ppron3:sg:inst:m3:ter:akc:npraep', 19),
#  ('adj:pl:acc:f:sup', 19),
#  ('adj:pl:gen:m1:com', 19),
#  ('pact:pl:acc:m1:imperf:aff', 18),
#  ('adj:sg:inst:m3:com', 18),
#  ('adj:sg:gen:n:sup', 18),
#  ('adj:pl:nom:m1:sup', 17),
#  ('ppas:sg:inst:m1:perf:aff', 17),
#  ('pact:sg:inst:n:imperf:aff', 17),
#  ('ppron3:pl:loc:f:ter:akc:praep', 17),
#  ('praet:pl:m2:perf', 17),
#  ('adj:sg:inst:m2:pos', 17),
#  ('ppas:sg:gen:n:imperf:aff', 17),
#  ('pact:sg:acc:n:imperf:aff', 17),
#  ('ppas:sg:inst:f:imperf:aff', 17),
#  ('ppron3:pl:acc:m1:ter:akc:praep', 16),
#  ('adj:sg:inst:m1:sup', 16),
#  ('pact:pl:inst:f:imperf:aff', 16),
#  ('ppron3:sg:gen:m3:ter:akc:praep', 16),
#  ('adj:pl:nom:f:sup', 16),
#  ('num:pl:inst:f:congr', 16),
#  ('praet:sg:m3:perf:nagl', 16),
#  ('ppas:sg:acc:m3:imperf:aff', 16),
#  ('ppron12:sg:dat:m1:sec:akc', 16),
#  ('ppas:pl:loc:m3:imperf:aff', 15),
#  ('adj:sg:inst:n:com', 15),
#  ('winien:pl:n:imperf', 15),
#  ('adjc', 15),
#  ('pact:sg:loc:n:imperf:aff', 15),
#  ('subst:pl:loc:m2', 14),
#  ('ppron3:sg:gen:n:ter:akc:praep', 14),
#  ('ppas:pl:inst:n:perf:aff', 14),
#  ('ppron3:sg:loc:n:ter:akc:npraep', 14),
#  ('ppas:sg:inst:m3:imperf:aff', 14),
#  ('adj:sg:loc:f:sup', 14),
#  ('adj:pl:gen:n:sup', 13),
#  ('adj:pl:nom:n:sup', 13),
#  ('ppas:sg:acc:n:imperf:aff', 13),
#  ('praet:pl:m2:imperf', 13),
#  ('adj:sg:inst:f:com', 13),
#  ('pact:pl:dat:m1:imperf:aff', 12),
#  ('subst:sg:dat:m2', 12),
#  ('ppas:pl:acc:m1:perf:aff', 12),
#  ('adj:sg:gen:m1:sup', 12),
#  ('adj:sg:loc:n:com', 12),
#  ('ppas:pl:inst:m3:imperf:aff', 12),
#  ('ppron12:sg:inst:f:pri', 12),
#  ('ppron3:pl:nom:n:ter:akc:npraep', 12),
#  ('ppas:pl:loc:f:imperf:aff', 11),
#  ('adj:pl:nom:n:com', 11),
#  ('pact:pl:dat:f:imperf:aff', 11),
#  ('ppas:pl:inst:f:imperf:aff', 11),
#  ('adj:pl:loc:m3:com', 11),
#  ('pact:pl:inst:m1:imperf:aff', 10),
#  ('adj:pl:acc:n:sup', 10),
#  ('pact:sg:dat:m1:imperf:aff', 10),
#  ('adj:pl:loc:m3:sup', 10),
#  ('adj:pl:gen:n:com', 10),
#  ('ppron3:sg:gen:n:ter:nakc:npraep', 10),
#  ('ppron12:sg:loc:f:pri', 10),
#  ('num:pl:dat:f:congr', 10),
#  ('ppas:sg:acc:m1:perf:aff', 10),
#  ('ppron3:sg:dat:m1:ter:akc:praep', 9),
#  ('pact:pl:loc:n:imperf:aff', 9),
#  ('ppron3:pl:loc:m3:ter:akc:praep', 9),
#  ('num:pl:loc:m1:congr', 9),
#  ('ppron3:pl:acc:m3:ter:akc:praep', 9),
#  ('adj:pl:loc:f:com', 9),
#  ('ppron12:sg:inst:m1:sec', 9),
#  ('adj:sg:voc:n:pos', 9),
#  ('adj:sg:loc:m2:pos', 9),
#  ('adj:pl:acc:n:com', 9),
#  ('subst:pl:dat:m2', 8),
#  ('ppron3:pl:loc:m1:ter:akc:praep', 8),
#  ('num:pl:inst:n:congr', 8),
#  ('pact:pl:inst:n:imperf:aff', 8),
#  ('ppas:pl:dat:m1:perf:aff', 8),
#  ('num:pl:inst:m1:congr', 8),
#  ('ppron12:sg:acc:f:sec:akc', 8),
#  ('ppas:sg:nom:m2:perf:aff', 8),
#  ('adj:pl:inst:m1:sup', 8),
#  ('praet:sg:m1:perf:agl', 8),
#  ('ppron12:sg:inst:f:sec', 8),
#  ('ppas:sg:loc:n:imperf:aff', 8),
#  ('ppron12:sg:gen:f:sec:akc', 8),
#  ('subst:sg:voc:m2', 8),
#  ('ppron3:sg:dat:f:ter:akc:praep', 8),
#  ('ppas:sg:inst:m1:imperf:aff', 7),
#  ('ppas:pl:dat:f:perf:aff', 7),
#  ('ppas:sg:inst:n:imperf:aff', 7),
#  ('ppron12:sg:loc:m1:pri', 7),
#  ('adj:sg:loc:n:sup', 7),
#  ('pact:pl:loc:m1:imperf:aff', 7),
#  ('ger:sg:gen:n:imperf:neg', 7),
#  ('adj:sg:acc:m1:sup', 7),
#  ('ppron3:sg:dat:m1:ter:akc:npraep', 7),
#  ('adj:sg:gen:m1:com', 7),
#  ('ppron3:pl:dat:m1:ter:akc:praep', 6),
#  ('ppron3:pl:inst:n:ter:akc:npraep', 6),
#  ('ppron3:sg:dat:m2:ter:nakc:npraep', 6),
#  ('ppas:sg:gen:m1:imperf:aff', 6),
#  ('ppas:sg:gen:f:perf:neg', 6),
#  ('adj:sg:voc:m3:pos', 6),
#  ('subst:sg:voc:m3', 6),
#  ('ppron3:pl:acc:f:ter:akc:praep', 6),
#  ('ppron12:sg:loc:f:sec', 6),
#  ('ppas:pl:acc:n:imperf:aff', 6),
#  ('ppas:sg:nom:f:perf:neg', 6),
#  ('num:sg:acc:m3:rec', 6),
#  ('ppron12:pl:loc:m1:pri', 6),
#  ('adj:pl:acc:m1:sup', 6),
#  ('ppas:pl:inst:m1:perf:aff', 6),
#  ('adj:pl:loc:m2:pos', 5),
#  ('num:pl:gen:m1:rec', 5),
#  ('ppron3:sg:acc:m1:ter:akc:npraep', 5),
#  ('adj:sg:dat:f:sup', 5),
#  ('pact:sg:nom:m1:imperf:neg', 5),
#  ('ppron12:sg:gen:m1:sec:nakc', 5),
#  ('pact:sg:dat:f:imperf:aff', 5),
#  ('ppas:sg:dat:m1:perf:aff', 5),
#  ('ppron3:pl:dat:m3:ter:akc:npraep', 5),
#  ('ppron12:pl:inst:m1:sec', 5),
#  ('ppas:sg:acc:m2:perf:aff', 5),
#  ('adj:pl:loc:f:sup', 5),
#  ('adj:pl:inst:m2:pos', 5),
#  ('ppas:pl:dat:m3:perf:aff', 5),
#  ('adj:pl:inst:f:sup', 5),
#  ('bedzie:pl:sec:imperf', 5),
#  ('ger:sg:gen:n:perf:neg', 5),
#  ('ppas:sg:dat:f:perf:aff', 5),
#  ('pact:pl:dat:n:imperf:aff', 5),
#  ('ppron3:sg:acc:n:ter:akc:praep', 4),
#  ('ppron3:pl:dat:n:ter:akc:npraep', 4),
#  ('ppas:sg:dat:f:imperf:aff', 4),
#  ('ppas:pl:loc:n:imperf:aff', 4),
#  ('ger:sg:nom:n:perf:neg', 4),
#  ('ppas:sg:acc:m1:imperf:aff', 4),
#  ('adj:sg:dat:f:com', 4),
#  ('pact:sg:nom:f:imperf:neg', 4),
#  ('adj:sg:dat:n:com', 4),
#  ('ppas:sg:nom:m1:imperf:neg', 4),
#  ('pact:sg:gen:m3:imperf:neg', 4),
#  ('ppas:sg:nom:m3:perf:neg', 4),
#  ('adj:pl:loc:n:com', 4),
#  ('ppron3:sg:gen:m1:ter:nakc:praep', 4),
#  ('ppas:pl:nom:m2:perf:aff', 4),
#  ('ppron3:pl:inst:m3:ter:akc:npraep', 4),
#  ('ppas:sg:gen:m2:perf:aff', 4),
#  ('ppron3:sg:dat:m3:ter:nakc:npraep', 4),
#  ('ppas:sg:nom:m1:perf:neg', 4),
#  ('ppron3:sg:inst:n:ter:akc:npraep', 4),
#  ('pact:sg:nom:m2:imperf:aff', 4),
#  ('pact:sg:gen:f:imperf:neg', 4),
#  ('pact:sg:loc:m1:imperf:aff', 4),
#  ('num:sg:nom:m3:rec', 3),
#  ('ppas:pl:gen:m3:imperf:neg', 3),
#  ('ger:sg:acc:n:perf:neg', 3),
#  ('adj:pl:inst:m3:sup', 3),
#  ('pact:pl:gen:f:imperf:neg', 3),
#  ('ppas:sg:nom:n:perf:neg', 3),
#  ('ppas:pl:gen:m3:perf:neg', 3),
#  ('adj:pl:dat:m1:sup', 3),
#  ('ppron3:sg:acc:m3:ter:nakc:praep', 3),
#  ('ppron12:sg:dat:f:sec:akc', 3),
#  ('pact:sg:inst:m2:imperf:aff', 3),
#  ('num:pl:gen:n:rec', 3),
#  ('adj:sg:voc:f:sup', 3),
#  ('ppron3:sg:acc:m2:ter:nakc:npraep', 3),
#  ('ppron3:sg:dat:n:ter:nakc:npraep', 3),
#  ('num:sg:acc:f:rec', 3),
#  ('num:sg:acc:n:rec', 3),
#  ('ppron3:pl:gen:m2:ter:akc:npraep', 3),
#  ('ppas:pl:nom:f:perf:neg', 3),
#  ('ppron12:sg:acc:m1:pri:nakc', 3),
#  ('num:pl:dat:m1:congr', 3),
#  ('ppas:sg:dat:n:perf:aff', 3),
#  ('num:pl:gen:m3:rec', 3),
#  ('ppas:pl:gen:m2:perf:aff', 2),
#  ('ppas:pl:loc:f:perf:neg', 2),
#  ('ppron3:pl:gen:m2:ter:akc:praep', 2),
#  ('adj:sg:inst:m1:com', 2),
#  ('ppas:pl:dat:m3:imperf:aff', 2),
#  ('num:sg:gen:m3:rec', 2),
#  ('ppas:pl:dat:m1:imperf:aff', 2),
#  ('pact:pl:dat:m3:imperf:aff', 2),
#  ('ppron3:pl:acc:n:ter:akc:praep', 2),
#  ('ppas:sg:dat:n:imperf:aff', 2),
#  ('adj:pl:dat:m2:pos', 2),
#  ('ppron12:sg:loc:m1:sec', 2),
#  ('numcol:pl:gen:n:congr', 2),
#  ('pact:sg:inst:m3:imperf:neg', 2),
#  ('ger:sg:nom:n:imperf:neg', 2),
#  ('pact:sg:acc:f:imperf:neg', 2),
#  ('ppas:sg:loc:f:imperf:neg', 2),
#  ('praet:sg:m2:perf:nagl', 2),
#  ('ger:sg:loc:n:perf:neg', 2),
#  ('adj:pl:inst:m1:com', 2),
#  ('ppron3:pl:dat:m2:ter:akc:npraep', 2),
#  ('ppas:pl:inst:n:imperf:aff', 2),
#  ('num:pl:gen:f:rec', 2),
#  ('ppas:pl:loc:m1:perf:aff', 2),
#  ('pact:pl:nom:f:imperf:neg', 2),
#  ('pact:pl:gen:m1:imperf:neg', 2),
#  ('ppron3:sg:gen:m2:ter:akc:npraep', 2),
#  ('ppas:sg:inst:n:imperf:neg', 2),
#  ('ppas:pl:gen:m1:imperf:neg', 2),
#  ('adj:pl:nom:m2:sup', 2),
#  ('pact:pl:nom:m2:imperf:aff', 2),
#  ('adj:pl:loc:n:sup', 2),
#  ('ppas:sg:gen:f:imperf:neg', 2),
#  ('ppas:pl:nom:m1:perf:neg', 2),
#  ('num:sg:loc:m3:rec', 2),
#  ('adj:pl:dat:f:com', 2),
#  ('ppas:pl:gen:f:imperf:neg', 2),
#  ('ppas:sg:acc:f:imperf:neg', 2),
#  ('adj:sg:dat:m1:com', 2),
#  ('ppas:sg:nom:m2:imperf:aff', 2),
#  ('pact:sg:dat:n:imperf:aff', 2),
#  ('ppron12:pl:loc:m1:sec', 2),
#  ('ppron12:sg:acc:f:pri:nakc', 2),
#  ('ger:sg:acc:n:imperf:neg', 2),
#  ('pact:pl:gen:n:imperf:neg', 2),
#  ('ppas:sg:dat:m1:imperf:aff', 2),
#  ('num:pl:inst:m2:congr', 2),
#  ('ppron3:sg:loc:m2:ter:akc:npraep', 2),
#  ('ppron12:pl:gen:f:pri', 2),
#  ('ppas:sg:acc:m3:imperf:neg', 2),
#  ('ppron12:sg:dat:f:pri:akc', 2),
#  ('ppron3:sg:acc:m3:ter:akc:praep', 2),
#  ('adj:pl:inst:m3:com', 2),
#  ('pact:pl:acc:m2:imperf:aff', 2),
#  ('ppas:sg:dat:m3:perf:aff', 2),
#  ('ppas:pl:inst:m1:imperf:aff', 2),
#  ('pact:sg:acc:m2:imperf:aff', 2),
#  ('adj:sg:loc:m1:sup', 1),
#  ('num:pl:loc:m2:congr', 1),
#  ('ppron12:sg:nom:m2:pri', 1),
#  ('ppron3:sg:gen:m2:ter:akc:praep', 1),
#  ('ppron12:sg:dat:m2:pri:nakc', 1),
#  ('num:pl:loc:m2:rec', 1),
#  ('ppron3:sg:acc:m2:ter:akc:praep', 1),
#  ('ppas:sg:loc:m1:imperf:aff', 1),
#  ('ppas:pl:loc:m2:imperf:aff', 1),
#  ('ppas:pl:dat:f:imperf:aff', 1),
#  ('pact:pl:acc:n:imperf:neg', 1),
#  ('subst:sg:voc:n', 1),
#  ('pact:sg:dat:m1:imperf:neg', 1),
#  ('num:sg:nom:m3:congr', 1),
#  ('ppas:sg:dat:m2:perf:aff', 1),
#  ('ger:sg:dat:n:imperf:neg', 1),
#  ('ppas:pl:nom:m3:imperf:neg', 1),
#  ('ppas:sg:gen:n:perf:neg', 1),
#  ('pact:sg:inst:f:imperf:neg', 1),
#  ('ppas:sg:acc:f:perf:neg', 1),
#  ('ppas:pl:nom:f:imperf:neg', 1),
#  ('ppron3:sg:acc:m1:ter:nakc:praep', 1),
#  ('ppas:sg:gen:m3:perf:neg', 1),
#  ('pact:sg:inst:n:imperf:neg', 1),
#  ('ppas:sg:inst:f:perf:neg', 1),
#  ('pact:sg:nom:n:imperf:neg', 1),
#  ('ppron3:pl:nom:m2:ter:akc:npraep', 1),
#  ('ppron12:sg:gen:m1:pri', 1),
#  ('ppas:sg:loc:f:perf:neg', 1),
#  ('num:sg:nom:n:rec', 1),
#  ('ppas:pl:nom:m2:imperf:aff', 1),
#  ('ppas:pl:acc:m2:perf:aff', 1),
#  ('pact:sg:nom:m3:imperf:neg', 1),
#  ('ppron12:sg:acc:m3:pri:akc', 1),
#  ('adj:sg:voc:m1:sup', 1),
#  ('numcol:pl:nom:n:rec', 1),
#  ('ppron12:pl:gen:f:sec', 1),
#  ('ppas:sg:inst:m2:perf:aff', 1),
#  ('pact:pl:gen:m2:imperf:aff', 1),
#  ('pact:sg:loc:m3:imperf:neg', 1),
#  ('adj:sg:inst:m2:sup', 1),
#  ('pact:pl:dat:m1:imperf:neg', 1),
#  ('ppas:sg:acc:m2:perf:neg', 1),
#  ('ppron3:pl:inst:m2:ter:akc:npraep', 1),
#  ('adj:sg:gen:m2:sup', 1),
#  ('pact:sg:gen:m1:imperf:neg', 1),
#  ('ppas:pl:gen:f:perf:neg', 1),
#  ('ppron12:sg:gen:m2:pri:akc', 1),
#  ('ger:sg:loc:n:imperf:neg', 1),
#  ('ppron12:pl:dat:f:sec', 1),
#  ('adj:sg:dat:m1:sup', 1),
#  ('ppron12:sg:acc:n:pri:akc', 1),
#  ('adj:sg:acc:m1:com', 1),
#  ('num:pl:dat:m3:congr', 1),
#  ('num:pl:inst:m1:rec', 1),
#  ('ppron12:pl:acc:f:pri', 1),
#  ('ppas:sg:inst:m1:imperf:neg', 1),
#  ('ppron3:sg:inst:m2:ter:akc:npraep', 1),
#  ('adj:pl:acc:m2:com', 1),
#  ('ppas:pl:acc:m1:imperf:aff', 1),
#  ('adj:sg:voc:m2:pos', 1),
#  ('ppron12:pl:acc:f:sec', 1),
#  ('praet:sg:m2:imperf:nagl', 1),
#  ('ppas:pl:acc:m3:perf:neg', 1),
#  ('pact:pl:loc:m3:imperf:neg', 1),
#  ('ppas:pl:gen:m2:imperf:aff', 1),
#  ('pact:pl:nom:n:imperf:neg', 1),
#  ('ppas:sg:loc:m3:perf:neg', 1),
#  ('num:sg:nom:f:rec', 1),
#  ('ppas:pl:nom:m3:perf:neg', 1),
#  ('ppron12:sg:nom:m2:sec', 1),
#  ('adj:sg:nom:m2:com', 1),
#  ('ppron3:pl:acc:m2:ter:akc:npraep', 1),
#  ('ppas:sg:loc:m1:perf:aff', 1),
#  ('ppron12:pl:inst:f:pri', 1),
#  ('ppas:sg:inst:n:perf:neg', 1),
#  ('ppas:pl:inst:m1:imperf:neg', 1),
#  ('adj:pl:inst:n:com', 1),
#  ('pact:sg:dat:m3:imperf:aff', 1),
#  ('ppas:pl:loc:m1:imperf:aff', 1),
#  ('ppas:sg:acc:m2:imperf:aff', 1),
#  ('adj:sg:dat:m2:pos', 1),
#  ('ppron12:sg:acc:m2:pri:akc', 1),
#  ('winien:pl:m2:imperf', 1),
#  ('ppas:pl:gen:m1:perf:neg', 1),
#  ('pact:pl:nom:m1:imperf:neg', 1),
#  ('ppas:sg:nom:f:imperf:neg', 1),
#  ('ppron12:sg:inst:m2:pri', 1),
#  ('ppas:pl:inst:m3:perf:neg', 1),
#  ('ppron12:pl:dat:f:pri', 1),
#  ('adj:pl:dat:f:sup', 1),
#  ('ppron12:sg:loc:m3:pri', 1),
#  ('adj:pl:dat:m3:com', 1),
#  ('pact:pl:acc:f:imperf:neg', 1),
#  ('ppron12:pl:nom:f:pri', 1),
#  ('ppas:pl:nom:n:imperf:neg', 1),
#  ('ppas:sg:acc:m1:perf:neg', 1),
#  ('adj:pl:inst:f:com', 1)]

# %%
unique_tags = np.unique(all_tags)

# %%
len(unique_tags)
# Out:
# 779

# %%
grammatic_classes = np.unique([t.split(':')[0] for t in unique_tags])

# %%
grammatic_classes = Counter([t.split(':')[0] for t in all_tags])

# %%
for grammar_class in grammatic_classes:
    print('\n' + '#'*100)
    print(grammar_class)
    print('#'*100 + '\n')
    class_tags = [t for t in unique_tags if t.split(':')[0] == grammar_class]
    print(' | '.join(class_tags))
# Out:
# ####################################################################################################
# praet
# ####################################################################################################
#
# praet:pl:f:imperf | praet:pl:f:perf | praet:pl:m1:imperf | praet:pl:m1:perf | praet:pl:m2:imperf | praet:pl:m2:perf | praet:pl:m3:imperf | praet:pl:m3:perf | praet:pl:n:imperf | praet:pl:n:perf | praet:sg:f:imperf | praet:sg:f:perf | praet:sg:m1:imperf | praet:sg:m1:imperf:agl | praet:sg:m1:imperf:nagl | praet:sg:m1:perf | praet:sg:m1:perf:agl | praet:sg:m1:perf:nagl | praet:sg:m2:imperf | praet:sg:m2:imperf:nagl | praet:sg:m2:perf | praet:sg:m2:perf:nagl | praet:sg:m3:imperf | praet:sg:m3:imperf:nagl | praet:sg:m3:perf | praet:sg:m3:perf:nagl | praet:sg:n:imperf | praet:sg:n:perf
#
# ####################################################################################################
# subst
# ####################################################################################################
#
# subst:pl:acc:f | subst:pl:acc:m1 | subst:pl:acc:m2 | subst:pl:acc:m3 | subst:pl:acc:n | subst:pl:dat:f | subst:pl:dat:m1 | subst:pl:dat:m2 | subst:pl:dat:m3 | subst:pl:dat:n | subst:pl:gen:f | subst:pl:gen:m1 | subst:pl:gen:m2 | subst:pl:gen:m3 | subst:pl:gen:n | subst:pl:inst:f | subst:pl:inst:m1 | subst:pl:inst:m2 | subst:pl:inst:m3 | subst:pl:inst:n | subst:pl:loc:f | subst:pl:loc:m1 | subst:pl:loc:m2 | subst:pl:loc:m3 | subst:pl:loc:n | subst:pl:nom:f | subst:pl:nom:m1 | subst:pl:nom:m2 | subst:pl:nom:m3 | subst:pl:nom:n | subst:sg:acc:f | subst:sg:acc:m1 | subst:sg:acc:m2 | subst:sg:acc:m3 | subst:sg:acc:n | subst:sg:dat:f | subst:sg:dat:m1 | subst:sg:dat:m2 | subst:sg:dat:m3 | subst:sg:dat:n | subst:sg:gen:f | subst:sg:gen:m1 | subst:sg:gen:m2 | subst:sg:gen:m3 | subst:sg:gen:n | subst:sg:inst:f | subst:sg:inst:m1 | subst:sg:inst:m2 | subst:sg:inst:m3 | subst:sg:inst:n | subst:sg:loc:f | subst:sg:loc:m1 | subst:sg:loc:m2 | subst:sg:loc:m3 | subst:sg:loc:n | subst:sg:nom:f | subst:sg:nom:m1 | subst:sg:nom:m2 | subst:sg:nom:m3 | subst:sg:nom:n | subst:sg:voc:f | subst:sg:voc:m1 | subst:sg:voc:m2 | subst:sg:voc:m3 | subst:sg:voc:n
#
# ####################################################################################################
# prep
# ####################################################################################################
#
# prep:acc | prep:acc:nwok | prep:acc:wok | prep:dat | prep:gen | prep:gen:nwok | prep:gen:wok | prep:inst | prep:inst:nwok | prep:inst:wok | prep:loc | prep:loc:nwok | prep:loc:wok | prep:nom
#
# ####################################################################################################
# adj
# ####################################################################################################
#
# adj:pl:acc:f:com | adj:pl:acc:f:pos | adj:pl:acc:f:sup | adj:pl:acc:m1:pos | adj:pl:acc:m1:sup | adj:pl:acc:m2:com | adj:pl:acc:m2:pos | adj:pl:acc:m3:com | adj:pl:acc:m3:pos | adj:pl:acc:m3:sup | adj:pl:acc:n:com | adj:pl:acc:n:pos | adj:pl:acc:n:sup | adj:pl:dat:f:com | adj:pl:dat:f:pos | adj:pl:dat:f:sup | adj:pl:dat:m1:pos | adj:pl:dat:m1:sup | adj:pl:dat:m2:pos | adj:pl:dat:m3:com | adj:pl:dat:m3:pos | adj:pl:dat:n:pos | adj:pl:gen:f:com | adj:pl:gen:f:pos | adj:pl:gen:f:sup | adj:pl:gen:m1:com | adj:pl:gen:m1:pos | adj:pl:gen:m1:sup | adj:pl:gen:m2:pos | adj:pl:gen:m3:com | adj:pl:gen:m3:pos | adj:pl:gen:m3:sup | adj:pl:gen:n:com | adj:pl:gen:n:pos | adj:pl:gen:n:sup | adj:pl:inst:f:com | adj:pl:inst:f:pos | adj:pl:inst:f:sup | adj:pl:inst:m1:com | adj:pl:inst:m1:pos | adj:pl:inst:m1:sup | adj:pl:inst:m2:pos | adj:pl:inst:m3:com | adj:pl:inst:m3:pos | adj:pl:inst:m3:sup | adj:pl:inst:n:com | adj:pl:inst:n:pos | adj:pl:loc:f:com | adj:pl:loc:f:pos | adj:pl:loc:f:sup | adj:pl:loc:m1:pos | adj:pl:loc:m2:pos | adj:pl:loc:m3:com | adj:pl:loc:m3:pos | adj:pl:loc:m3:sup | adj:pl:loc:n:com | adj:pl:loc:n:pos | adj:pl:loc:n:sup | adj:pl:nom:f:com | adj:pl:nom:f:pos | adj:pl:nom:f:sup | adj:pl:nom:m1:com | adj:pl:nom:m1:pos | adj:pl:nom:m1:sup | adj:pl:nom:m2:pos | adj:pl:nom:m2:sup | adj:pl:nom:m3:com | adj:pl:nom:m3:pos | adj:pl:nom:m3:sup | adj:pl:nom:n:com | adj:pl:nom:n:pos | adj:pl:nom:n:sup | adj:sg:acc:f:com | adj:sg:acc:f:pos | adj:sg:acc:f:sup | adj:sg:acc:m1:com | adj:sg:acc:m1:pos | adj:sg:acc:m1:sup | adj:sg:acc:m2:pos | adj:sg:acc:m3:com | adj:sg:acc:m3:pos | adj:sg:acc:m3:sup | adj:sg:acc:n:com | adj:sg:acc:n:pos | adj:sg:acc:n:sup | adj:sg:dat:f:com | adj:sg:dat:f:pos | adj:sg:dat:f:sup | adj:sg:dat:m1:com | adj:sg:dat:m1:pos | adj:sg:dat:m1:sup | adj:sg:dat:m2:pos | adj:sg:dat:m3:pos | adj:sg:dat:n:com | adj:sg:dat:n:pos | adj:sg:gen:f:com | adj:sg:gen:f:pos | adj:sg:gen:f:sup | adj:sg:gen:m1:com | adj:sg:gen:m1:pos | adj:sg:gen:m1:sup | adj:sg:gen:m2:pos | adj:sg:gen:m2:sup | adj:sg:gen:m3:com | adj:sg:gen:m3:pos | adj:sg:gen:m3:sup | adj:sg:gen:n:com | adj:sg:gen:n:pos | adj:sg:gen:n:sup | adj:sg:inst:f:com | adj:sg:inst:f:pos | adj:sg:inst:f:sup | adj:sg:inst:m1:com | adj:sg:inst:m1:pos | adj:sg:inst:m1:sup | adj:sg:inst:m2:pos | adj:sg:inst:m2:sup | adj:sg:inst:m3:com | adj:sg:inst:m3:pos | adj:sg:inst:m3:sup | adj:sg:inst:n:com | adj:sg:inst:n:pos | adj:sg:inst:n:sup | adj:sg:loc:f:com | adj:sg:loc:f:pos | adj:sg:loc:f:sup | adj:sg:loc:m1:pos | adj:sg:loc:m1:sup | adj:sg:loc:m2:pos | adj:sg:loc:m3:com | adj:sg:loc:m3:pos | adj:sg:loc:m3:sup | adj:sg:loc:n:com | adj:sg:loc:n:pos | adj:sg:loc:n:sup | adj:sg:nom:f:com | adj:sg:nom:f:pos | adj:sg:nom:f:sup | adj:sg:nom:m1:com | adj:sg:nom:m1:pos | adj:sg:nom:m1:sup | adj:sg:nom:m2:com | adj:sg:nom:m2:pos | adj:sg:nom:m3:com | adj:sg:nom:m3:pos | adj:sg:nom:m3:sup | adj:sg:nom:n:com | adj:sg:nom:n:pos | adj:sg:nom:n:sup | adj:sg:voc:f:pos | adj:sg:voc:f:sup | adj:sg:voc:m1:pos | adj:sg:voc:m1:sup | adj:sg:voc:m2:pos | adj:sg:voc:m3:pos | adj:sg:voc:n:pos
#
# ####################################################################################################
# interp
# ####################################################################################################
#
# interp
#
# ####################################################################################################
# qub
# ####################################################################################################
#
# qub
#
# ####################################################################################################
# conj
# ####################################################################################################
#
# conj
#
# ####################################################################################################
# inf
# ####################################################################################################
#
# inf:imperf | inf:perf
#
# ####################################################################################################
# comp
# ####################################################################################################
#
# comp
#
# ####################################################################################################
# siebie
# ####################################################################################################
#
# siebie:acc | siebie:dat | siebie:gen | siebie:inst | siebie:loc
#
# ####################################################################################################
# adv
# ####################################################################################################
#
# adv | adv:com | adv:pos | adv:sup
#
# ####################################################################################################
# fin
# ####################################################################################################
#
# fin:pl:pri:imperf | fin:pl:pri:perf | fin:pl:sec:imperf | fin:pl:sec:perf | fin:pl:ter:imperf | fin:pl:ter:perf | fin:sg:pri:imperf | fin:sg:pri:perf | fin:sg:sec:imperf | fin:sg:sec:perf | fin:sg:ter:imperf | fin:sg:ter:perf
#
# ####################################################################################################
# ppron3
# ####################################################################################################
#
# ppron3:pl:acc:f:ter:akc:npraep | ppron3:pl:acc:f:ter:akc:praep | ppron3:pl:acc:m1:ter:akc:npraep | ppron3:pl:acc:m1:ter:akc:praep | ppron3:pl:acc:m2:ter:akc:npraep | ppron3:pl:acc:m3:ter:akc:npraep | ppron3:pl:acc:m3:ter:akc:praep | ppron3:pl:acc:n:ter:akc:npraep | ppron3:pl:acc:n:ter:akc:praep | ppron3:pl:dat:f:ter:akc:npraep | ppron3:pl:dat:m1:ter:akc:npraep | ppron3:pl:dat:m1:ter:akc:praep | ppron3:pl:dat:m2:ter:akc:npraep | ppron3:pl:dat:m3:ter:akc:npraep | ppron3:pl:dat:n:ter:akc:npraep | ppron3:pl:gen:f:ter:akc:npraep | ppron3:pl:gen:f:ter:akc:praep | ppron3:pl:gen:m1:ter:akc:npraep | ppron3:pl:gen:m1:ter:akc:praep | ppron3:pl:gen:m2:ter:akc:npraep | ppron3:pl:gen:m2:ter:akc:praep | ppron3:pl:gen:m3:ter:akc:npraep | ppron3:pl:gen:m3:ter:akc:praep | ppron3:pl:gen:n:ter:akc:npraep | ppron3:pl:gen:n:ter:akc:praep | ppron3:pl:inst:f:ter:akc:npraep | ppron3:pl:inst:m1:ter:akc:npraep | ppron3:pl:inst:m2:ter:akc:npraep | ppron3:pl:inst:m3:ter:akc:npraep | ppron3:pl:inst:n:ter:akc:npraep | ppron3:pl:loc:f:ter:akc:praep | ppron3:pl:loc:m1:ter:akc:praep | ppron3:pl:loc:m3:ter:akc:praep | ppron3:pl:loc:n:ter:akc:praep | ppron3:pl:nom:f:ter:akc:npraep | ppron3:pl:nom:m1:ter:akc:npraep | ppron3:pl:nom:m2:ter:akc:npraep | ppron3:pl:nom:m3:ter:akc:npraep | ppron3:pl:nom:n:ter:akc:npraep | ppron3:sg:acc:f:ter:akc:npraep | ppron3:sg:acc:f:ter:akc:praep | ppron3:sg:acc:m1:ter:akc:npraep | ppron3:sg:acc:m1:ter:akc:praep | ppron3:sg:acc:m1:ter:nakc:npraep | ppron3:sg:acc:m1:ter:nakc:praep | ppron3:sg:acc:m2:ter:akc:praep | ppron3:sg:acc:m2:ter:nakc:npraep | ppron3:sg:acc:m3:ter:akc:praep | ppron3:sg:acc:m3:ter:nakc:npraep | ppron3:sg:acc:m3:ter:nakc:praep | ppron3:sg:acc:n:ter:akc:npraep | ppron3:sg:acc:n:ter:akc:praep | ppron3:sg:dat:f:ter:akc:npraep | ppron3:sg:dat:f:ter:akc:praep | ppron3:sg:dat:m1:ter:akc:npraep | ppron3:sg:dat:m1:ter:akc:praep | ppron3:sg:dat:m1:ter:nakc:npraep | ppron3:sg:dat:m2:ter:nakc:npraep | ppron3:sg:dat:m3:ter:nakc:npraep | ppron3:sg:dat:n:ter:nakc:npraep | ppron3:sg:gen:f:ter:akc:npraep | ppron3:sg:gen:f:ter:akc:praep | ppron3:sg:gen:m1:ter:akc:npraep | ppron3:sg:gen:m1:ter:akc:praep | ppron3:sg:gen:m1:ter:nakc:npraep | ppron3:sg:gen:m1:ter:nakc:praep | ppron3:sg:gen:m2:ter:akc:npraep | ppron3:sg:gen:m2:ter:akc:praep | ppron3:sg:gen:m3:ter:akc:npraep | ppron3:sg:gen:m3:ter:akc:praep | ppron3:sg:gen:m3:ter:nakc:npraep | ppron3:sg:gen:n:ter:akc:npraep | ppron3:sg:gen:n:ter:akc:praep | ppron3:sg:gen:n:ter:nakc:npraep | ppron3:sg:inst:f:ter:akc:praep | ppron3:sg:inst:m1:ter:akc:npraep | ppron3:sg:inst:m2:ter:akc:npraep | ppron3:sg:inst:m3:ter:akc:npraep | ppron3:sg:inst:n:ter:akc:npraep | ppron3:sg:loc:f:ter:akc:npraep | ppron3:sg:loc:m1:ter:akc:npraep | ppron3:sg:loc:m2:ter:akc:npraep | ppron3:sg:loc:m3:ter:akc:npraep | ppron3:sg:loc:n:ter:akc:npraep | ppron3:sg:nom:f:ter:akc:npraep | ppron3:sg:nom:m1:ter:akc:npraep | ppron3:sg:nom:m3:ter:akc:npraep | ppron3:sg:nom:n:ter:akc:npraep
#
# ####################################################################################################
# ppas
# ####################################################################################################
#
# ppas:pl:acc:f:imperf:aff | ppas:pl:acc:f:perf:aff | ppas:pl:acc:m1:imperf:aff | ppas:pl:acc:m1:perf:aff | ppas:pl:acc:m2:perf:aff | ppas:pl:acc:m3:imperf:aff | ppas:pl:acc:m3:perf:aff | ppas:pl:acc:m3:perf:neg | ppas:pl:acc:n:imperf:aff | ppas:pl:acc:n:perf:aff | ppas:pl:dat:f:imperf:aff | ppas:pl:dat:f:perf:aff | ppas:pl:dat:m1:imperf:aff | ppas:pl:dat:m1:perf:aff | ppas:pl:dat:m3:imperf:aff | ppas:pl:dat:m3:perf:aff | ppas:pl:gen:f:imperf:aff | ppas:pl:gen:f:imperf:neg | ppas:pl:gen:f:perf:aff | ppas:pl:gen:f:perf:neg | ppas:pl:gen:m1:imperf:aff | ppas:pl:gen:m1:imperf:neg | ppas:pl:gen:m1:perf:aff | ppas:pl:gen:m1:perf:neg | ppas:pl:gen:m2:imperf:aff | ppas:pl:gen:m2:perf:aff | ppas:pl:gen:m3:imperf:aff | ppas:pl:gen:m3:imperf:neg | ppas:pl:gen:m3:perf:aff | ppas:pl:gen:m3:perf:neg | ppas:pl:gen:n:imperf:aff | ppas:pl:gen:n:perf:aff | ppas:pl:inst:f:imperf:aff | ppas:pl:inst:f:perf:aff | ppas:pl:inst:m1:imperf:aff | ppas:pl:inst:m1:imperf:neg | ppas:pl:inst:m1:perf:aff | ppas:pl:inst:m3:imperf:aff | ppas:pl:inst:m3:perf:aff | ppas:pl:inst:m3:perf:neg | ppas:pl:inst:n:imperf:aff | ppas:pl:inst:n:perf:aff | ppas:pl:loc:f:imperf:aff | ppas:pl:loc:f:perf:aff | ppas:pl:loc:f:perf:neg | ppas:pl:loc:m1:imperf:aff | ppas:pl:loc:m1:perf:aff | ppas:pl:loc:m2:imperf:aff | ppas:pl:loc:m3:imperf:aff | ppas:pl:loc:m3:perf:aff | ppas:pl:loc:n:imperf:aff | ppas:pl:loc:n:perf:aff | ppas:pl:nom:f:imperf:aff | ppas:pl:nom:f:imperf:neg | ppas:pl:nom:f:perf:aff | ppas:pl:nom:f:perf:neg | ppas:pl:nom:m1:imperf:aff | ppas:pl:nom:m1:perf:aff | ppas:pl:nom:m1:perf:neg | ppas:pl:nom:m2:imperf:aff | ppas:pl:nom:m2:perf:aff | ppas:pl:nom:m3:imperf:aff | ppas:pl:nom:m3:imperf:neg | ppas:pl:nom:m3:perf:aff | ppas:pl:nom:m3:perf:neg | ppas:pl:nom:n:imperf:aff | ppas:pl:nom:n:imperf:neg | ppas:pl:nom:n:perf:aff | ppas:sg:acc:f:imperf:aff | ppas:sg:acc:f:imperf:neg | ppas:sg:acc:f:perf:aff | ppas:sg:acc:f:perf:neg | ppas:sg:acc:m1:imperf:aff | ppas:sg:acc:m1:perf:aff | ppas:sg:acc:m1:perf:neg | ppas:sg:acc:m2:imperf:aff | ppas:sg:acc:m2:perf:aff | ppas:sg:acc:m2:perf:neg | ppas:sg:acc:m3:imperf:aff | ppas:sg:acc:m3:imperf:neg | ppas:sg:acc:m3:perf:aff | ppas:sg:acc:n:imperf:aff | ppas:sg:acc:n:perf:aff | ppas:sg:dat:f:imperf:aff | ppas:sg:dat:f:perf:aff | ppas:sg:dat:m1:imperf:aff | ppas:sg:dat:m1:perf:aff | ppas:sg:dat:m2:perf:aff | ppas:sg:dat:m3:perf:aff | ppas:sg:dat:n:imperf:aff | ppas:sg:dat:n:perf:aff | ppas:sg:gen:f:imperf:aff | ppas:sg:gen:f:imperf:neg | ppas:sg:gen:f:perf:aff | ppas:sg:gen:f:perf:neg | ppas:sg:gen:m1:imperf:aff | ppas:sg:gen:m1:perf:aff | ppas:sg:gen:m2:perf:aff | ppas:sg:gen:m3:imperf:aff | ppas:sg:gen:m3:perf:aff | ppas:sg:gen:m3:perf:neg | ppas:sg:gen:n:imperf:aff | ppas:sg:gen:n:perf:aff | ppas:sg:gen:n:perf:neg | ppas:sg:inst:f:imperf:aff | ppas:sg:inst:f:perf:aff | ppas:sg:inst:f:perf:neg | ppas:sg:inst:m1:imperf:aff | ppas:sg:inst:m1:imperf:neg | ppas:sg:inst:m1:perf:aff | ppas:sg:inst:m2:perf:aff | ppas:sg:inst:m3:imperf:aff | ppas:sg:inst:m3:perf:aff | ppas:sg:inst:n:imperf:aff | ppas:sg:inst:n:imperf:neg | ppas:sg:inst:n:perf:aff | ppas:sg:inst:n:perf:neg | ppas:sg:loc:f:imperf:aff | ppas:sg:loc:f:imperf:neg | ppas:sg:loc:f:perf:aff | ppas:sg:loc:f:perf:neg | ppas:sg:loc:m1:imperf:aff | ppas:sg:loc:m1:perf:aff | ppas:sg:loc:m3:imperf:aff | ppas:sg:loc:m3:perf:aff | ppas:sg:loc:m3:perf:neg | ppas:sg:loc:n:imperf:aff | ppas:sg:loc:n:perf:aff | ppas:sg:nom:f:imperf:aff | ppas:sg:nom:f:imperf:neg | ppas:sg:nom:f:perf:aff | ppas:sg:nom:f:perf:neg | ppas:sg:nom:m1:imperf:aff | ppas:sg:nom:m1:imperf:neg | ppas:sg:nom:m1:perf:aff | ppas:sg:nom:m1:perf:neg | ppas:sg:nom:m2:imperf:aff | ppas:sg:nom:m2:perf:aff | ppas:sg:nom:m3:imperf:aff | ppas:sg:nom:m3:perf:aff | ppas:sg:nom:m3:perf:neg | ppas:sg:nom:n:imperf:aff | ppas:sg:nom:n:perf:aff | ppas:sg:nom:n:perf:neg
#
# ####################################################################################################
# num
# ####################################################################################################
#
# num:pl:acc:f:congr | num:pl:acc:f:rec | num:pl:acc:m1:congr | num:pl:acc:m1:rec | num:pl:acc:m2:congr | num:pl:acc:m2:rec | num:pl:acc:m3:congr | num:pl:acc:m3:rec | num:pl:acc:n:congr | num:pl:acc:n:rec | num:pl:dat:f:congr | num:pl:dat:m1:congr | num:pl:dat:m3:congr | num:pl:gen:f:congr | num:pl:gen:f:rec | num:pl:gen:m1:congr | num:pl:gen:m1:rec | num:pl:gen:m2:congr | num:pl:gen:m3:congr | num:pl:gen:m3:rec | num:pl:gen:n:congr | num:pl:gen:n:rec | num:pl:inst:f:congr | num:pl:inst:m1:congr | num:pl:inst:m1:rec | num:pl:inst:m2:congr | num:pl:inst:m3:congr | num:pl:inst:n:congr | num:pl:loc:f:congr | num:pl:loc:m1:congr | num:pl:loc:m2:congr | num:pl:loc:m2:rec | num:pl:loc:m3:congr | num:pl:loc:n:congr | num:pl:nom:f:congr | num:pl:nom:f:rec | num:pl:nom:m1:congr | num:pl:nom:m1:rec | num:pl:nom:m2:congr | num:pl:nom:m2:rec | num:pl:nom:m3:congr | num:pl:nom:m3:rec | num:pl:nom:n:congr | num:pl:nom:n:rec | num:sg:acc:f:rec | num:sg:acc:m3:rec | num:sg:acc:n:rec | num:sg:gen:m3:rec | num:sg:loc:m3:rec | num:sg:nom:f:rec | num:sg:nom:m3:congr | num:sg:nom:m3:rec | num:sg:nom:n:rec
#
# ####################################################################################################
# pact
# ####################################################################################################
#
# pact:pl:acc:f:imperf:aff | pact:pl:acc:f:imperf:neg | pact:pl:acc:m1:imperf:aff | pact:pl:acc:m2:imperf:aff | pact:pl:acc:m3:imperf:aff | pact:pl:acc:n:imperf:aff | pact:pl:acc:n:imperf:neg | pact:pl:dat:f:imperf:aff | pact:pl:dat:m1:imperf:aff | pact:pl:dat:m1:imperf:neg | pact:pl:dat:m3:imperf:aff | pact:pl:dat:n:imperf:aff | pact:pl:gen:f:imperf:aff | pact:pl:gen:f:imperf:neg | pact:pl:gen:m1:imperf:aff | pact:pl:gen:m1:imperf:neg | pact:pl:gen:m2:imperf:aff | pact:pl:gen:m3:imperf:aff | pact:pl:gen:n:imperf:aff | pact:pl:gen:n:imperf:neg | pact:pl:inst:f:imperf:aff | pact:pl:inst:m1:imperf:aff | pact:pl:inst:m3:imperf:aff | pact:pl:inst:n:imperf:aff | pact:pl:loc:f:imperf:aff | pact:pl:loc:m1:imperf:aff | pact:pl:loc:m3:imperf:aff | pact:pl:loc:m3:imperf:neg | pact:pl:loc:n:imperf:aff | pact:pl:nom:f:imperf:aff | pact:pl:nom:f:imperf:neg | pact:pl:nom:m1:imperf:aff | pact:pl:nom:m1:imperf:neg | pact:pl:nom:m2:imperf:aff | pact:pl:nom:m3:imperf:aff | pact:pl:nom:n:imperf:aff | pact:pl:nom:n:imperf:neg | pact:sg:acc:f:imperf:aff | pact:sg:acc:f:imperf:neg | pact:sg:acc:m1:imperf:aff | pact:sg:acc:m2:imperf:aff | pact:sg:acc:m3:imperf:aff | pact:sg:acc:n:imperf:aff | pact:sg:dat:f:imperf:aff | pact:sg:dat:m1:imperf:aff | pact:sg:dat:m1:imperf:neg | pact:sg:dat:m3:imperf:aff | pact:sg:dat:n:imperf:aff | pact:sg:gen:f:imperf:aff | pact:sg:gen:f:imperf:neg | pact:sg:gen:m1:imperf:aff | pact:sg:gen:m1:imperf:neg | pact:sg:gen:m3:imperf:aff | pact:sg:gen:m3:imperf:neg | pact:sg:gen:n:imperf:aff | pact:sg:inst:f:imperf:aff | pact:sg:inst:f:imperf:neg | pact:sg:inst:m1:imperf:aff | pact:sg:inst:m2:imperf:aff | pact:sg:inst:m3:imperf:aff | pact:sg:inst:m3:imperf:neg | pact:sg:inst:n:imperf:aff | pact:sg:inst:n:imperf:neg | pact:sg:loc:f:imperf:aff | pact:sg:loc:m1:imperf:aff | pact:sg:loc:m3:imperf:aff | pact:sg:loc:m3:imperf:neg | pact:sg:loc:n:imperf:aff | pact:sg:nom:f:imperf:aff | pact:sg:nom:f:imperf:neg | pact:sg:nom:m1:imperf:aff | pact:sg:nom:m1:imperf:neg | pact:sg:nom:m2:imperf:aff | pact:sg:nom:m3:imperf:aff | pact:sg:nom:m3:imperf:neg | pact:sg:nom:n:imperf:aff | pact:sg:nom:n:imperf:neg
#
# ####################################################################################################
# imps
# ####################################################################################################
#
# imps:imperf | imps:perf
#
# ####################################################################################################
# pcon
# ####################################################################################################
#
# pcon:imperf
#
# ####################################################################################################
# pant
# ####################################################################################################
#
# pant:perf
#
# ####################################################################################################
# ger
# ####################################################################################################
#
# ger:sg:acc:n:imperf:aff | ger:sg:acc:n:imperf:neg | ger:sg:acc:n:perf:aff | ger:sg:acc:n:perf:neg | ger:sg:dat:n:imperf:aff | ger:sg:dat:n:imperf:neg | ger:sg:dat:n:perf:aff | ger:sg:gen:n:imperf:aff | ger:sg:gen:n:imperf:neg | ger:sg:gen:n:perf:aff | ger:sg:gen:n:perf:neg | ger:sg:inst:n:imperf:aff | ger:sg:inst:n:perf:aff | ger:sg:loc:n:imperf:aff | ger:sg:loc:n:imperf:neg | ger:sg:loc:n:perf:aff | ger:sg:loc:n:perf:neg | ger:sg:nom:n:imperf:aff | ger:sg:nom:n:imperf:neg | ger:sg:nom:n:perf:aff | ger:sg:nom:n:perf:neg
#
# ####################################################################################################
# brev
# ####################################################################################################
#
# brev:npun | brev:pun
#
# ####################################################################################################
# aglt
# ####################################################################################################
#
# aglt:pl:pri:imperf:nwok | aglt:pl:sec:imperf:nwok | aglt:sg:pri:imperf:nwok | aglt:sg:pri:imperf:wok | aglt:sg:sec:imperf:nwok | aglt:sg:sec:imperf:wok
#
# ####################################################################################################
# pred
# ####################################################################################################
#
# pred
#
# ####################################################################################################
# ppron12
# ####################################################################################################
#
# ppron12:pl:acc:f:pri | ppron12:pl:acc:f:sec | ppron12:pl:acc:m1:pri | ppron12:pl:acc:m1:sec | ppron12:pl:dat:f:pri | ppron12:pl:dat:f:sec | ppron12:pl:dat:m1:pri | ppron12:pl:dat:m1:sec | ppron12:pl:gen:f:pri | ppron12:pl:gen:f:sec | ppron12:pl:gen:m1:pri | ppron12:pl:gen:m1:sec | ppron12:pl:inst:f:pri | ppron12:pl:inst:m1:pri | ppron12:pl:inst:m1:sec | ppron12:pl:loc:m1:pri | ppron12:pl:loc:m1:sec | ppron12:pl:nom:f:pri | ppron12:pl:nom:m1:pri | ppron12:pl:nom:m1:sec | ppron12:sg:acc:f:pri:akc | ppron12:sg:acc:f:pri:nakc | ppron12:sg:acc:f:sec:akc | ppron12:sg:acc:f:sec:nakc | ppron12:sg:acc:m1:pri:akc | ppron12:sg:acc:m1:pri:nakc | ppron12:sg:acc:m1:sec:akc | ppron12:sg:acc:m1:sec:nakc | ppron12:sg:acc:m2:pri:akc | ppron12:sg:acc:m3:pri:akc | ppron12:sg:acc:n:pri:akc | ppron12:sg:dat:f:pri:akc | ppron12:sg:dat:f:pri:nakc | ppron12:sg:dat:f:sec:akc | ppron12:sg:dat:f:sec:nakc | ppron12:sg:dat:m1:pri:akc | ppron12:sg:dat:m1:pri:nakc | ppron12:sg:dat:m1:sec:akc | ppron12:sg:dat:m1:sec:nakc | ppron12:sg:dat:m2:pri:nakc | ppron12:sg:gen:f:pri:akc | ppron12:sg:gen:f:sec:akc | ppron12:sg:gen:m1:pri | ppron12:sg:gen:m1:pri:akc | ppron12:sg:gen:m1:sec:akc | ppron12:sg:gen:m1:sec:nakc | ppron12:sg:gen:m2:pri:akc | ppron12:sg:inst:f:pri | ppron12:sg:inst:f:sec | ppron12:sg:inst:m1:pri | ppron12:sg:inst:m1:sec | ppron12:sg:inst:m2:pri | ppron12:sg:loc:f:pri | ppron12:sg:loc:f:sec | ppron12:sg:loc:m1:pri | ppron12:sg:loc:m1:sec | ppron12:sg:loc:m3:pri | ppron12:sg:nom:f:pri | ppron12:sg:nom:f:sec | ppron12:sg:nom:m1:pri | ppron12:sg:nom:m1:sec | ppron12:sg:nom:m2:pri | ppron12:sg:nom:m2:sec
#
# ####################################################################################################
# winien
# ####################################################################################################
#
# winien:pl:f:imperf | winien:pl:m1:imperf | winien:pl:m2:imperf | winien:pl:m3:imperf | winien:pl:n:imperf | winien:sg:f:imperf | winien:sg:m1:imperf | winien:sg:m3:imperf | winien:sg:n:imperf
#
# ####################################################################################################
# bedzie
# ####################################################################################################
#
# bedzie:pl:pri:imperf | bedzie:pl:sec:imperf | bedzie:pl:ter:imperf | bedzie:sg:pri:imperf | bedzie:sg:sec:imperf | bedzie:sg:ter:imperf
#
# ####################################################################################################
# adjp
# ####################################################################################################
#
# adjp
#
# ####################################################################################################
# interj
# ####################################################################################################
#
# interj
#
# ####################################################################################################
# impt
# ####################################################################################################
#
# impt:pl:pri:imperf | impt:pl:pri:perf | impt:pl:sec:imperf | impt:pl:sec:perf | impt:sg:sec:imperf | impt:sg:sec:perf
#
# ####################################################################################################
# adja
# ####################################################################################################
#
# adja
#
# ####################################################################################################
# burk
# ####################################################################################################
#
# burk
#
# ####################################################################################################
# depr
# ####################################################################################################
#
# depr:pl:nom:m2
#
# ####################################################################################################
# xxx
# ####################################################################################################
#
# xxx
#
# ####################################################################################################
# numcol
# ####################################################################################################
#
# numcol:pl:gen:n:congr | numcol:pl:nom:n:rec
#
# ####################################################################################################
# adjc
# ####################################################################################################
#
# adjc
